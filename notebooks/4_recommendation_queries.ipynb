# %% [markdown]
# # Book Recommendation System Demo
#
# This notebook demonstrates how to use the recommendation scripts as importable modules.
# We will initialize the database connections once and pass them to the various recommendation functions.
#
# ## 1. Setup and Database Connection

# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv
from sqlalchemy import create_engine, text
from pymongo import MongoClient
from pymongo.server_api import ServerApi
from importlib import reload

# 1. Setup Path FIRST so Python can find the 'scripts' folder
# Find project root by walking up until a 'scripts' folder is found
PROJECT_ROOT = Path.cwd().parent

# Add project root to system path
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# 2. Now you can safely import project modules
import scripts.queries.query_helper 
reload(scripts.queries.query_helper)
from scripts.queries.query_helper import execute_query, QUERIES

# Load environment variables
load_dotenv(PROJECT_ROOT / ".env")

# Database Configuration
db_name = os.getenv("DB_NAME", "bookrec")
host = os.getenv("HOST", "localhost")
msql_user = os.getenv("MSQL_USER")
msql_password = os.getenv("MSQL_PASSWORD")
msql_port = os.getenv("MSQL_PORT", "3306")
mdb_user = os.getenv("MDB_USER")
mdb_password = os.getenv("MDB_PASSWORD")
mdb_cluster = os.getenv("MDB_CLUSTER")
mdb_appname = os.getenv("MDB_APPNAME", "Cluster0")
mdb_port = os.getenv("MDB_PORT", "27017")
mdb_use_atlas = os.getenv("MDB_USE_ATLAS", "false").lower() == "true"

# Initialize MySQL Engine
mysql_engine = create_engine(
    f"mysql+mysqlconnector://{msql_user}:{msql_password}@{host}:{msql_port}/{db_name}"
)

# Initialize MongoDB Client
if mdb_use_atlas:
    mongodb_uri = f"mongodb+srv://{mdb_user}:{mdb_password}@{mdb_cluster}/?retryWrites=true&w=majority&appName={mdb_appname}"
    mongo_client = MongoClient(mongodb_uri, server_api=ServerApi('1'))
else:
    mongodb_uri = f"mongodb://{host}:{mdb_port}/"
    mongo_client = MongoClient(mongodb_uri)

mongo_db = mongo_client[db_name]

print("Database connections established.")
# Out:
# Database connections established.

# %%
print("AVAILABLE QUERIES:\n")
print('-' * 50)
for query_type, query_info in QUERIES.items():
    print(f"\n{query_type} Queries:\n")
    if query_type == 'Hybrid':
        # Hybrid structure is flattened (no DB sub-key)
        for query_name, query in query_info.items():
            print(f"   - Query name: {query_name}")
            print(f"   - Query description: {query.get('description')}")
            print(f"     - Query variables: {query.get('variables')}")
            print(f"   - Query {query.get('how')} join, with the keys: {query.get('join_keys')}")
            print(f"   - Databases for join: {{'left': {query['left_query']['db_type']}, 'right': {query['right_query']['db_type']}}}\n")
        print('-' * 50)
        continue
    
    for database, query_meta in query_info.items():
            print(f" - Database: [{database}]\n")
            for query_name, query in query_meta.items():
                print(f"   - Query name: {query_name}")
                print(f"   - Query description: {query.get('description')}")
                print(f"     - Query variables: {query.get('variables')}\n")

    print('-' * 50)
# Out:
# AVAILABLE QUERIES:
#
# --------------------------------------------------
#
# Simple Queries:
#
#  - Database: [MySQL]
#
#    - Query name: top_books
#    - Query description: Popularity-based recommendation: find top books with highest number of rating counts
#      - Query variables: ['limit']
#
#  - Database: [MongoDB]
#
#    - Query name: top_books
#    - Query description: Popularity-based recommendation: find top books with highest number of rating counts
#      - Query variables: ['limit']
#
#    - Query name: price_range
#    - Query description: Find top M books within price range (Low/High) with good avg rating
#      - Query variables: ['low', 'high', 'min_avg', 'limit']
#
# --------------------------------------------------
#
# Complex Queries:
#
#  - Database: [MySQL]
#
#    - Query name: top_recent_books
# ...

# %%
users_to_test = {
# Information gathered from users table
    'has_ratings' : { # boolean column
        True : [],
        False : []
    },
    'has_preferences' : { # boolean column
        True : [],  
        False : []
    },
    'has_valid_location' : [] # has both latitude and longitude defined
}   

def _sample_users_by_bool(col: str, val: bool, limit: int = 5):
    """Return up to `limit` user_id's where `col` equals boolean `val` (MySQL stores booleans as 1/0)."""
    v = 1 if val else 0
    q = text(f"SELECT user_id FROM users WHERE {col} = :v LIMIT :limit")
    with mysql_engine.connect() as conn:
        return [row[0] for row in conn.execute(q, {"v": v, "limit": limit}).fetchall()]

# Sample has_ratings / has_preferences
users_to_test["has_ratings"][True] = _sample_users_by_bool("has_ratings", True, 5)
users_to_test["has_ratings"][False] = _sample_users_by_bool("has_ratings", False, 5)
users_to_test["has_preferences"][True] = _sample_users_by_bool("has_preferences", True, 5)
users_to_test["has_preferences"][False] = _sample_users_by_bool("has_preferences", False, 5)

# Sample users with valid location (both latitude and longitude present)
with mysql_engine.connect() as conn:
    users_to_test["has_valid_location"] = [row[0] for row in conn.execute(text("""
        SELECT user_id FROM users 
        WHERE loc_latitude IS NOT NULL AND loc_longitude IS NOT NULL 
        LIMIT 5"""
    )).fetchall()]

print("Test users sampled successfully.")
print("Users to test:")
for key, val in users_to_test.items():
    print(f" - {key}: {val}")
# Out:
# Test users sampled successfully.
# Users to test:
#  - has_ratings: {True: [2, 8, 9, 10, 12], False: [1, 3, 4, 5, 6]}
#  - has_preferences: {True: [2, 8, 9, 10, 12], False: [1, 3, 4, 5, 6]}
#  - has_valid_location: [1, 2, 3, 4, 5]

# %%
# Check that all databases aren't empty
print(f"{'DATABASE':<10} | {'TABLE/COLLECTION':<25} | {'COUNT':<10} | {'STATUS':<10}")
print("-" * 65)

# 1. Check MySQL Tables
mysql_tables = ['users', 'books', 'ratings', 'root_genres', 'subgenres', 'book_root_genres', 'book_subgenres']

with mysql_engine.connect() as conn:
    for table in mysql_tables:
        try:
            count = conn.execute(text(f"SELECT COUNT(*) FROM {table}")).scalar()
            count = count if count is not None else 0
            status = "✅ OK" if count > 0 else "⚠️ EMPTY"
            print(f"{'MySQL':<10} | {table:<25} | {count:<10} | {status}")
        except Exception as e:
            print(f"{'MySQL':<10} | {table:<25} | -          | ❌ ERROR")

print("-" * 65)

# 2. Check MongoDB Collections
mongo_colls = ['books_metadata', 'users_profiles']

for coll_name in mongo_colls:
    try:
        count = mongo_db[coll_name].count_documents({})
        status = "✅ OK" if count > 0 else "⚠️ EMPTY"
        print(f"{'MongoDB':<10} | {coll_name:<25} | {count:<10} | {status}")
    except Exception as e:
        print(f"{'MongoDB':<10} | {coll_name:<25} | -          | ❌ ERROR")
# Out:
# DATABASE   | TABLE/COLLECTION          | COUNT      | STATUS
# -----------------------------------------------------------------
# MySQL      | users                     | 278858     | ✅ OK
# MySQL      | books                     | 266457     | ✅ OK
# MySQL      | ratings                   | 1016676    | ✅ OK
# MySQL      | root_genres               | 28         | ✅ OK
# MySQL      | subgenres                 | 99         | ✅ OK
# MySQL      | book_root_genres          | 13504      | ✅ OK
# MySQL      | book_subgenres            | 13513      | ✅ OK
# -----------------------------------------------------------------
# MongoDB    | books_metadata            | 266457     | ✅ OK
# MongoDB    | users_profiles            | 278858     | ✅ OK

# %%
# DEBUGGING CELL: Test individual queries manually

print("--- DEBUGGING INDIVIDUAL QUERIES ---")

# 1. Test MySQL Connection & Simple Query directly
print("\n1. Testing MySQL Direct Query...")
with mysql_engine.connect() as conn:
    # Simple count to verify connectivity
    cnt = conn.execute(text("SELECT COUNT(*) FROM ratings")).scalar()
    print(f"   Ratings count: {cnt}")
    
    # Run the actual top_books SQL manually
    sql = """
        SELECT isbn, COUNT(*) AS rating_count
        FROM ratings
        GROUP BY isbn
        ORDER BY rating_count DESC
        LIMIT 5;
    """
    try:
        res = conn.execute(text(sql)).fetchall()
        print(f"   Manual SQL Result: {res}")
    except Exception as e:
        print(f"   Manual SQL Error: {e}")

# 2. Test MongoDB Direct Query
print("\n2. Testing MongoDB Direct Query...")
try:
    pipeline = [
        { "$sort": { "rating_metrics.rating_count": -1 } },
        { "$limit": 5 },
        { "$project": { "isbn": "$_id", "rating_count": "$rating_metrics.rating_count", "_id": 0 }}
    ]
    res = list(mongo_db['books_metadata'].aggregate(pipeline))
    print(f"   Manual Mongo Result: {res}")
except Exception as e:
    print(f"   Manual Mongo Error: {e}")

# 3. Test via execute_query helper
print("\n3. Testing via execute_query() helper...")
raw_conn = mysql_engine.raw_connection()
cursor = raw_conn.cursor(dictionary=True)

try:
    # Test MySQL top_books
    res_mysql = execute_query(
        category='Simple', 
        db_type='MySQL', 
        query_name='top_books', 
        params={'limit': 5}, 
        sql_cursor=cursor, 
        mongo_db=mongo_db
    )
    print(f"   Helper MySQL Result Rows: {len(res_mysql.get('data', []))}")
    display(res_mysql['data'])

    # Test MongoDB top_books
    res_mongo = execute_query(
        category='Simple', 
        db_type='MongoDB', 
        query_name='top_books', 
        params={'limit': 5}, 
        sql_cursor=cursor, 
        mongo_db=mongo_db
    )
    print(f"   Helper MongoDB Result Rows: {len(res_mongo.get('data', []))}")
    display(res_mongo['data'])

finally:
    cursor.close()
    raw_conn.close()
# Out:
# --- DEBUGGING INDIVIDUAL QUERIES ---
#
# 1. Testing MySQL Direct Query...
#    Ratings count: 1016676
#    Manual SQL Result: [('0971880107', 2502), ('0316666343', 1295), ('0385504209', 883), ('0060928336', 732), ('0312195516', 723)]
#
# 2. Testing MongoDB Direct Query...
#    Manual Mongo Result: [{'isbn': '0374157065'}, {'isbn': '0393045218'}, {'isbn': '0002005018'}, {'isbn': '0195153448'}, {'isbn': '0060973129'}]
#
# 3. Testing via execute_query() helper...
# --- EXECUTION: top_books (MySQL) ---
#    Helper MySQL Result Rows: 5
#          isbn  rating_count
# 0  0971880107          2502
# 1  0316666343          1295
# 2  0385504209           883
# 3  0060928336           732
# 4  0312195516           723
# --- EXECUTION: top_books (MongoDB) ---
#    Helper MongoDB Result Rows: 5
#          isbn  rating_count
# 0  0971880107          2502
# 1  0316666343          1295
# 2  0385504209           883
# 3  0060928336           732
# 4  0312195516           723

# %%
import pandas as pd
from IPython.display import display

# ==========================================
# 1. SETUP & PARAMETERS
# ==========================================
test_params = {
    'limit': 7,
    'min_avg': 6,
    'min_supt': 3,
    'n_recent': 200,
    'low': 5,
    'high': 150,
    'proximity_radius': 4000,
    'user_id': None 
}

# Storage for the two sections of your report
performance_metrics = [] # Will hold: [Query Name, DB Type, Time, Rows, Status]
execution_details = []   # Will hold: [Query Name, Params, Result Head, Explain Plan]

def get_best_user_for_query(query_name):
    """(Helper function remains the same)"""
    # Geographic/Hybrid queries need valid location data
    if 'geographic' in query_name or 'hybrid' in query_name:
        if users_to_test['has_valid_location']:
            return users_to_test['has_valid_location'][0]
    # Profile/Content queries need preferences
    if 'profile' in query_name or 'content' in query_name:
        if users_to_test['has_preferences'][True]:
            return users_to_test['has_preferences'][True][0]
    # Default fallback
    if users_to_test['has_ratings'][True]:
        return users_to_test['has_ratings'][True][0]
    return 1

# ==========================================
# 2. EXECUTION PHASE (Collect Data)
# ==========================================
raw_conn = mysql_engine.raw_connection()

try:
    cursor = raw_conn.cursor(dictionary=True)
    print("🚀 Starting Batch Execution...\n")

    # Helper to process a single query entry
    def process_query(category, db_type, query_name):
        # 1. Prepare Parameters
        current_params = test_params.copy()
        current_params['user_id'] = get_best_user_for_query(query_name)
        
        # Filter params to show only those used by the query
        if category == 'Hybrid':
            q_def = QUERIES[category][query_name]
        else:
            q_def = QUERIES[category][db_type][query_name]
            
        needed_vars = q_def.get('variables', [])
        filtered_params = {k: current_params[k] for k in needed_vars if k in current_params}

        # 2. Run Execution (Timing & Data)
        try:
            res_exec = execute_query(
                category=category, db_type=db_type, query_name=query_name,
                params=current_params, sql_cursor=cursor, mongo_db=mongo_db,
                mode='execution'
            )
            
            # Handle Errors Gracefully
            if 'error' in res_exec:
                performance_metrics.append({
                    "Category": category, "DB": db_type, "Query": query_name,
                    "Status": "❌ Failed", "Time (s)": 0, "Rows": 0, "Error": res_exec['error']
                })
                return

            # Success - Store Metrics
            duration = res_exec.get('duration_seconds', 0)
            df = res_exec.get('data')
            rows = len(df) if df is not None else 0
            
            performance_metrics.append({
                "Category": category, "DB": db_type, "Query": query_name,
                "Status": "✅ Success", "Time (s)": round(duration, 4), "Rows": rows
            })

            # 3. Run Explain (Analysis)
            res_explain = execute_query(
                category=category, db_type=db_type, query_name=query_name,
                params=current_params, sql_cursor=cursor, mongo_db=mongo_db,
                mode='explain'
            )
            
            # 4. Store Details for later display
            # Note: We store only df.head() to save memory
            execution_details.append({
                "meta": f"{category} | {db_type} | {query_name}",
                "params": filtered_params,
                "data": df if df is not None and not df.empty else None,
                "explain_plan": res_explain.get('explain_plan')
            })

        except Exception as e:
            performance_metrics.append({
                "Category": category, "DB": db_type, "Query": query_name,
                "Status": "❌ Crash", "Time (s)": 0, "Rows": 0, "Error": str(e)
            })

    # --- Main Loop ---
    for category, content in QUERIES.items():
        # Handle Hybrid (Flattened)
        if category == 'Hybrid':
            for q_name in content.keys():
                if not q_name.endswith('_INDEX'):
                    process_query(category, 'Combined', q_name)
        # Handle Standard (Nested)
        else:
            for db_type, queries in content.items():
                for q_name in queries.keys():
                    if not q_name.endswith('_INDEX'):
                        process_query(category, db_type, q_name)

finally:
    cursor.close()
    raw_conn.close()
    print("🏁 Execution Complete. Generating Reports...")

# ==========================================
# 3. REPORTING PHASE
# ==========================================

# --- SECTION 1: PERFORMANCE SUMMARY DATAFRAME ---
print("\n" + "="*80)
print("📊 SECTION 1: PERFORMANCE SUMMARY")
print("="*80)
df_results = pd.DataFrame(performance_metrics)
# Reorder columns for readability
cols = ["Category", "DB", "Query", "Status", "Time (s)", "Rows"]
if "Error" in df_results.columns: cols.append("Error")
display(df_results[cols])


# --- SECTION 2: DETAILED BREAKDOWN ---
print("\n\n" + "="*80)
print("🔍 SECTION 2: DETAILED QUERY LOGS (Sample + Plans)")
print("="*80)

for log in execution_details:
    print(f"\n🔹 {log['meta']}")
    print(f"   Params: {log['params']}")
    print("-" * 50)
    
    # 1. Data Sample
    print("📋 Result:")
    if log['data'] is not None:
        display(log['data'])
    else:
        print("   (No data returned)")

    # 2. Explain Plan
    print("\n🧠 Explain Plan:")
    plan = log['explain_plan']

    if plan is not None:
        if isinstance(plan, dict):
            # For Hybrid or Mongo multi-collection
            for k, v in plan.items():
                print(f"[{k}]:")
                if hasattr(v, 'head'): # It's a dataframe
                    display(v)
                else:
                    # Try to display dicts nicely, fallback to print
                    try:
                        display(v)
                    except:
                        print(v)
        elif hasattr(plan, 'head'):
            display(plan)
        else:
            print(plan)
    else:
        print("No explain plan available.")
                
    print("_" * 80)
# Out:
# 🚀 Starting Batch Execution...
#
# --- EXECUTION: top_books (MySQL) ---
# --- EXPLAIN: top_books (MySQL) ---
# --- EXECUTION: top_books (MongoDB) ---
# --- EXPLAIN: top_books (MongoDB) ---
# --- EXECUTION: price_range (MongoDB) ---
# --- EXPLAIN: price_range (MongoDB) ---
# --- EXECUTION: top_recent_books (MySQL) ---
# --- EXPLAIN: top_recent_books (MySQL) ---
# --- EXECUTION: collaborative_geographic (MySQL) ---
# --- EXPLAIN: collaborative_geographic (MySQL) ---
# --- EXECUTION: genre_collaborative (MySQL) ---
# --- EXPLAIN: genre_collaborative (MySQL) ---
# --- EXECUTION: user_profile_recommendation (MongoDB) ---
# --- EXPLAIN: user_profile_recommendation (MongoDB) ---
# --- EXECUTION: hybrid_personalized (Combined) ---
# --- EXPLAIN: hybrid_personalized (Combined) ---
# 🏁 Execution Complete. Generating Reports...
#
# ...
# 📊 SECTION 1: PERFORMANCE SUMMARY
# ...
#   Category        DB                        Query     Status  Time (s)  Rows
# ...

# %% [markdown]
# **Notes:**
# - When the recommendations are run several times, for the same user, the database management system will use cached results/ materialized views, so the execution will be faster!
# - Purely MongoDB recommendations dnon't include book-titles in the results, as they are not stored in MongoDB, ate the momment.
