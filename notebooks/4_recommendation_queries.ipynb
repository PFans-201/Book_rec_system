# %% [markdown]
# # Book Recommendation System Demo
#
# This notebook demonstrates how to use the recommendation scripts as importable modules.
# We will initialize the database connections once and pass them to the various recommendation functions.
#
# ## 1. Setup and Database Connection

# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv
from sqlalchemy import create_engine, text
from pymongo import MongoClient
from pymongo.server_api import ServerApi

# Find project root by walking up until a 'scripts' folder is found
PROJECT_ROOT = Path.cwd()
search_root = PROJECT_ROOT
while not (search_root / 'scripts').exists() and search_root != search_root.parent:
    search_root = search_root.parent
PROJECT_ROOT = search_root
sys.path.insert(0, str(PROJECT_ROOT))

# Load environment variables
load_dotenv(PROJECT_ROOT / ".env")

# Database Configuration
db_name = os.getenv("DB_NAME", "bookrec")
host = os.getenv("HOST", "localhost")
msql_user = os.getenv("MSQL_USER")
msql_password = os.getenv("MSQL_PASSWORD")
msql_port = os.getenv("MSQL_PORT", "3306")
mdb_user = os.getenv("MDB_USER")
mdb_password = os.getenv("MDB_PASSWORD")
mdb_cluster = os.getenv("MDB_CLUSTER")
mdb_appname = os.getenv("MDB_APPNAME", "Cluster0")
mdb_use_atlas = os.getenv("MDB_USE_ATLAS", "false").lower() == "true"

# Initialize MySQL Engine
mysql_engine = create_engine(
    f"mysql+mysqlconnector://{msql_user}:{msql_password}@{host}:{msql_port}/{db_name}"
)

# Initialize MongoDB Client
if mdb_use_atlas:
    mongodb_uri = f"mongodb+srv://{mdb_user}:{mdb_password}@{mdb_cluster}/?retryWrites=true&w=majority&appName={mdb_appname}"
    mongo_client = MongoClient(mongodb_uri, server_api=ServerApi('1'))
else:
    mongodb_uri = f"mongodb://{mdb_user}:{mdb_password}@{host}:27017/"
    mongo_client = MongoClient(mongodb_uri)

mongo_db = mongo_client[db_name]

print("Database connections established.")
# Out:
# Database connections established.

# %%
users_to_test = {
    # Information gathered from users table
    'has_ratings' : { # boolean column 
        True : [],
        False : []
    },
    'has_preferences' : { # boolean column
        True : [], 
        False : []
    },
    'has_valid_location' : [] # has both latitude and longitude defined
}

def _sample_users_by_bool(col: str, val: bool, limit: int = 5):
    """Return up to `limit` user_id's where `col` equals boolean `val` (MySQL stores booleans as 1/0)."""
    v = 1 if val else 0
    q = text(f"SELECT user_id FROM users WHERE {col} = :v LIMIT :limit")
    with mysql_engine.connect() as conn:
        return [row[0] for row in conn.execute(q, {"v": v, "limit": limit}).fetchall()]

# Sample has_ratings / has_preferences
users_to_test["has_ratings"][True] = _sample_users_by_bool("has_ratings", True, 5)
users_to_test["has_ratings"][False] = _sample_users_by_bool("has_ratings", False, 5)
users_to_test["has_preferences"][True] = _sample_users_by_bool("has_preferences", True, 5)
users_to_test["has_preferences"][False] = _sample_users_by_bool("has_preferences", False, 5)

# Sample users with valid location (both latitude and longitude present)
with mysql_engine.connect() as conn:
    q = text("""
        SELECT user_id FROM users
        WHERE loc_latitude IS NOT NULL AND loc_longitude IS NOT NULL
        LIMIT :limit
    """)
    users_to_test["has_valid_location"] = [r[0] for r in conn.execute(q, {"limit": 5}).fetchall()]

print("Sample of users to test:")
for key, val in users_to_test.items():
    if isinstance(val, dict):
        print(f" - {key}:")
        for bool, subval in val.items():
            print(f"   - {bool}: {subval}")
    else:   
        print(f" - {key}: {val}")
# Out:
# Sample of users to test:
#  - has_ratings:
#    - True: [2, 8, 9, 10, 12]
#    - False: [1, 3, 4, 5, 6]
#  - has_preferences:
#    - True: [2, 8, 9, 10, 12]
#    - False: [1, 3, 4, 5, 6]
#  - has_valid_location: [1, 2, 3, 4, 5]

# %%
# Enable auto-reloading of modules (Best practice for development)
# %load_ext autoreload
# %autoreload 2

import importlib
import scripts.recommendations.recommendation_content_based
import scripts.recommendations.recommendation_collaborative
import scripts.recommendations.recommendation_trending
import scripts.recommendations.recommendation_geographic
import scripts.recommendations.recommendation_diverse
import scripts.recommendations.recommendation_hybrid
import scripts.recommendations.recommendation_cold_start
import scripts.recommendations.recommendation_smart
import scripts.recommendations.query_taste_evolution

print("🔄 Force reloading recommendation modules...")
try:
    importlib.reload(scripts.recommendations.recommendation_content_based)
    importlib.reload(scripts.recommendations.recommendation_collaborative)
    importlib.reload(scripts.recommendations.recommendation_trending)
    importlib.reload(scripts.recommendations.recommendation_geographic)
    importlib.reload(scripts.recommendations.recommendation_diverse)
    importlib.reload(scripts.recommendations.recommendation_hybrid)
    importlib.reload(scripts.recommendations.recommendation_cold_start)
    importlib.reload(scripts.recommendations.recommendation_smart)
    importlib.reload(scripts.recommendations.query_taste_evolution)
    print("✅ Modules reloaded successfully. Re-run the cells below to use the latest code.")
except Exception as e:
    print(f"❌ Error reloading modules: {e}")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 🔄 Force reloading recommendation modules...
# ✅ Modules reloaded successfully. Re-run the cells below to use the latest code.

# %%
# Quick import smoke test for refactored modules
print("Running import smoke tests for recommendation modules...")
from importlib import import_module

modules = [
    'scripts.recommendations.recommendation_content_based',
    'scripts.recommendations.recommendation_collaborative',
    'scripts.recommendations.recommendation_trending',
    'scripts.recommendations.recommendation_geographic',
    'scripts.recommendations.recommendation_diverse',
    'scripts.recommendations.recommendation_hybrid'
]

for m in modules:
    try:
        mod = import_module(m)
        names = [n for n in dir(mod) if n.startswith('get_') or n.startswith('find_') or n.endswith('_recommendations')]
        print(f"{m}: \n\t{', '.join(names[:20])}")
    except Exception as e:
        print(f"{m}: IMPORT FAILED -> {e}")
# Out:
# Running import smoke tests for recommendation modules...
# scripts.recommendations.recommendation_content_based:
# 	display_recommendations, find_similar_books, get_user_favorite_authors, get_user_favorite_genres, get_user_highly_rated_books, get_user_preferences
# scripts.recommendations.recommendation_collaborative:
# 	display_recommendations, enrich_recommendations, find_similar_users, get_recommendations_from_similar_users, get_user_ratings
# scripts.recommendations.recommendation_trending:
# 	get_trending_books_by_velocity, get_trending_recommendations, get_user_preferred_genres
# scripts.recommendations.recommendation_geographic:
# 	enrich_recommendations, find_nearby_users, get_geographic_recommendations, get_regional_favorites, get_user_location
# scripts.recommendations.recommendation_diverse:
# 	enrich_recommendations, get_diverse_recommendations, get_user_author_distribution, get_user_genre_distribution
# scripts.recommendations.recommendation_hybrid:
# 	enrich_recommendations, find_similar_users_simple, get_hybrid_recommendations, get_user_favorite_genres, get_user_preferences, get_user_ratings

# %% [markdown]
# ## 2. Content-Based Filtering
# Recommends books based on similarity to books the user has rated highly (using genres, authors, etc.).

# %%
from scripts.recommendations.queries import {simple_mysql, query_content_based}


with mysql_engine.connect() as conn:
    result = conn.execute(text(simple_mysql))

# %%
from scripts.recommendations.recommendation_content_based import find_similar_books

# Test with users who have ratings
test_users = users_to_test['has_ratings'][True][:2]  # Test first 2 users

for user_id in test_users:
    print(f"\n--- Content-Based Recommendations for User {user_id} ---")
    try:
        content_recs = find_similar_books(mysql_engine, mongo_db, user_id, limit=5)
        # elapsed_time, res = rec(engines, user, args**)
        # print(f" Perfomance before: {elapsed_time}s")

        # add index 
        # excute()

        # elapsed_time, res = rec(engines, user, args**)
        # print(f" Perfomance after: {elapsed_time} s")

        if not content_recs:
            print("No recommendations found.")
        for book in content_recs:
            print(f"- {book.get('title', book.get('isbn'))} by {book.get('authors', 'N/A')} (Score: {book.get('score', 0):.2f})")
    except Exception as e:
        print(f"Error: {e}")
# Out:
# --- Content-Based Recommendations for User 2 ---
#
# 🎯 Finding content-based recommendations for User 2
# Favorite genres: []
# Favorite authors: []
# No recommendations found.
#
# --- Content-Based Recommendations for User 8 ---
#
# 🎯 Finding content-based recommendations for User 8
# Favorite genres: []
# Favorite authors: ['Julia Oliver']
# No recommendations found.
#
# 🎯 Finding content-based recommendations for User 2
# Favorite genres: []
# Favorite authors: []
# No recommendations found.
#
# --- Content-Based Recommendations for User 8 ---
#
# 🎯 Finding content-based recommendations for User 8
# Favorite genres: []
# Favorite authors: ['Julia Oliver']
# No recommendations found.

# %% [markdown]
# ## 3. Collaborative Filtering
# Recommends books based on what similar users liked.

# %%
from scripts.recommendations.recommendation_collaborative import (
    find_similar_users,
    get_recommendations_from_similar_users,
    enrich_recommendations as collab_enrich
)

# Test with users who have ratings
test_users = users_to_test['has_ratings'][True][:2]

for user_id in test_users:
    print(f"\n--- Collaborative Recommendations for User {user_id} ---")
    try:
        # Find similar users
        similar_users = find_similar_users(mysql_engine, user_id)
        print(f"Found {len(similar_users)} similar users")

        if similar_users:
            # Get raw recommendations and enrich with metadata
            recs_raw = get_recommendations_from_similar_users(mysql_engine, user_id, similar_users, limit=20)
            collab_recs = collab_enrich(mysql_engine, mongo_db, recs_raw)

            for book in collab_recs[:5]:
                print(f"- {book.get('title', book.get('isbn'))} by {book.get('authors', 'N/A')} (Score: {book.get('score', 0):.2f})")
        else:
            print("No similar users found.")
    except Exception as e:
        print(f"Error: {e}")
# Out:
# --- Collaborative Recommendations for User 2 ---
# Error: Python type tuple cannot be converted
#
# --- Collaborative Recommendations for User 8 ---
# Error: Python type tuple cannot be converted

# %% [markdown]
# ## 4. Hybrid Recommendation System
# Combines content-based and collaborative filtering, and incorporates user preferences from MongoDB.

# %%
from scripts.recommendations.recommendation_hybrid import get_hybrid_recommendations

# Test with users who have preferences (ideal for hybrid)
test_users = users_to_test['has_preferences'][True][:2]

for user_id in test_users:
    print(f"\n--- Hybrid Recommendations for User {user_id} ---")
    try:
        hybrid_recs = get_hybrid_recommendations(mysql_engine, mongo_db, user_id, limit=5)
        
        if not hybrid_recs:
            print("No recommendations found.")
            
        for book in hybrid_recs:
            print(f"- {book.get('title', 'Unknown')} by {book.get('authors', 'Unknown')} (Score: {book.get('score', 0):.2f})")
    except Exception as e:
        print(f"Error: {e}")
# Out:
# --- Hybrid Recommendations for User 2 ---
# Error: Python type tuple cannot be converted
#
# --- Hybrid Recommendations for User 8 ---
# Error: Python type tuple cannot be converted

# %% [markdown]
# ## 5. Handling Cold Start Problems
# Recommendations for new users or users with little history, based on demographics or popularity.

# %%
from scripts.recommendations.recommendation_cold_start import get_cold_start_recommendations

# Test with users who have NO ratings (Cold Start)
test_users = users_to_test['has_ratings'][False][:2]

for user_id in test_users:
    print(f"\n--- Cold Start Recommendations for User {user_id} ---")
    try:
        cold_start_recs = get_cold_start_recommendations(mysql_engine, mongo_db, user_id, limit=5)
        
        for book in cold_start_recs:
            print(f"- {book.get('title', 'Unknown')} by {book.get('authors', 'Unknown')} (Reason: {book.get('reason', 'N/A')})")
    except Exception as e:
        print(f"Error: {e}")
# Out:
# --- Cold Start Recommendations for User 1 ---
# Error: Python type tuple cannot be converted
#
# --- Cold Start Recommendations for User 3 ---
# Error: Python type tuple cannot be converted

# %% [markdown]
# ## 6. Geographic and Trending Recommendations
# Recommendations based on user location and current popularity trends.

# %%
from scripts.recommendations.recommendation_geographic import get_geographic_recommendations
from scripts.recommendations.recommendation_trending import get_trending_recommendations

# Test with users who have valid location
test_users = users_to_test['has_valid_location'][:2]

for user_id in test_users:
    print(f"\n--- Geographic Recommendations for User {user_id} ---")
    try:
        geo_recs = get_geographic_recommendations(mysql_engine, user_id, limit=5)
        if not geo_recs:
            print("No geographic recommendations found (maybe no nearby users).")
        for book in geo_recs:
            print(f"- {book.get('title', 'Unknown')} (Location Score: {book.get('location_score', 0):.2f})")
    except Exception as e:
        print(f"Error: {e}")

print(f"\n--- Trending Recommendations (Global) ---")
try:
    trending_recs = get_trending_recommendations(mysql_engine, mongo_db, limit=5)
    for book in trending_recs:
        print(f"- {book.get('title', 'Unknown')} (Momentum: {book.get('momentum', 0):.2f})")
except Exception as e:
    print(f"Error: {e}")
# Out:
# --- Geographic Recommendations for User 1 ---
# Error: Python type tuple cannot be converted
#
# --- Geographic Recommendations for User 2 ---
# Error: Python type tuple cannot be converted
#
# --- Geographic Recommendations for User 2 ---
# Error: Python type tuple cannot be converted
#
# --- Trending Recommendations (Global) ---
# Error: Python type tuple cannot be converted
#
# --- Trending Recommendations (Global) ---
# - Wild Animus (Momentum: 0.00)
# - Wild Animus (Momentum: 0.00)

# %% [markdown]
# ## 7. Diversity and Taste Evolution Analysis
# Ensuring variety in recommendations and analyzing how user taste changes over time.

# %%
from scripts.recommendations.recommendation_diverse import get_diverse_recommendations
from scripts.recommendations.query_taste_evolution import analyze_taste_evolution

# Test with users who have ratings
test_users = users_to_test['has_ratings'][True][:2]

for user_id in test_users:
    print(f"\n=== Analysis for User {user_id} ===")
    
    print(f"--- Diverse Recommendations ---")
    try:
        diverse_recs = get_diverse_recommendations(mysql_engine, user_id, limit=5)
        for book in diverse_recs:
            print(f"- {book.get('title', 'Unknown')} (Genre: {book.get('genre', 'N/A')})")
    except Exception as e:
        print(f"Error getting diverse recs: {e}")

    print(f"\n--- Taste Evolution ---")
    try:
        evolution = analyze_taste_evolution(mysql_engine, mongo_db, user_id)
        if evolution:
            print(f"Analyzed {len(evolution.get('timeline', []))} ratings.")
            if evolution.get('changes'):
                print("Detected taste changes:")
                for change in evolution['changes']:
                    print(f"- {change}")
            else:
                print("No significant taste changes detected.")
        else:
            print("No evolution data available.")
    except Exception as e:
        print(f"Error analyzing taste: {e}")
# Out:
# === Analysis for User 2 ===
# --- Diverse Recommendations ---
# Error getting diverse recs: get_diverse_recommendations() missing 1 required positional argument: 'user_id'
#
# --- Taste Evolution ---
# Error analyzing taste: (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'bookrec.books_subgenres' doesn't exist
# [SQL:
#             SELECT r.r_seq_user, rg.genre_name
#             FROM ratings r
#             JOIN books b ON r.isbn = b.isbn
#             JOIN books_subgenres bs ON b.isbn = bs.isbn
#             JOIN subgenres sg ON bs.subgenre_id = sg.subgenre_id
#             JOIN root_genres rg ON sg.root_genre_id = rg.root_genre_id
#             WHERE r.user_id = %(user_id)s
#             ORDER BY r.r_seq_user ASC
#         ]
# [parameters: {'user_id': 2}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#
# === Analysis for User 8 ===
# --- Diverse Recommendations ---
# Error getting diverse recs: get_diverse_recommendations() missing 1 required positional argument: 'user_id'
#
# --- Taste Evolution ---
# Error analyzing taste: (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'bookrec.books_subgenres' doesn't exist
# [SQL:
#             SELECT r.r_seq_user, rg.genre_name
#             FROM ratings r
#             JOIN books b ON r.isbn = b.isbn
#             JOIN books_subgenres bs ON b.isbn = bs.isbn
#             JOIN subgenres sg ON bs.subgenre_id = sg.subgenre_id
#             JOIN root_genres rg ON sg.root_genre_id = rg.root_genre_id
#             WHERE r.user_id = %(user_id)s
#             ORDER BY r.r_seq_user ASC
#         ]
# [parameters: {'user_id': 8}]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ## 8. Smart Recommendations
# Automatically selects the best strategy based on user profile (Ratings vs Preferences vs Location vs Cold Start).

# %%
from scripts.recommendations.recommendation_smart import get_smart_recommendations

# Test Smart Recommendations with different types of users

print("\n=== Testing Smart Recommendations ===")

# 1. User with Ratings (Should use Hybrid)
if users_to_test['has_ratings'][True]:
    u1 = users_to_test['has_ratings'][True][0]
    print(f"\n--- Case 1: User {u1} (Has Ratings) ---")
    recs = get_smart_recommendations(mysql_engine, mongo_db, u1, limit=5)
    for book in recs:
        print(f"- {book.get('title', 'Unknown')} (Score: {book.get('score', 0):.2f})")

# 2. User with Preferences only (Should use Preference-Based)
# Note: We need a user who has preferences but NO ratings to strictly test this path,
# but our sample might have both. The smart logic prioritizes ratings.
# Let's try a user from 'has_preferences' list.
if users_to_test['has_preferences'][True]:
    u2 = users_to_test['has_preferences'][True][0]
    print(f"\n--- Case 2: User {u2} (Has Preferences) ---")
    recs = get_smart_recommendations(mysql_engine, mongo_db, u2, limit=5)
    for book in recs:
        print(f"- {book.get('title', 'Unknown')} (Score: {book.get('score', 0):.2f})")

# 3. Cold Start User (Should use Cold Start/Trending)
if users_to_test['has_ratings'][False]:
    u3 = users_to_test['has_ratings'][False][0]
    print(f"\n--- Case 3: User {u3} (Cold Start) ---")
    recs = get_smart_recommendations(mysql_engine, mongo_db, u3, limit=5)
    for book in recs:
        print(f"- {book.get('title', 'Unknown')} (Reason: {book.get('reason', 'N/A')})")
# Out:
# === Testing Smart Recommendations ===
#
# --- Case 1: User 2 (Has Ratings) ---
# 🧠 Smart Strategy Analysis for User 2:
#    Ratings: True | Preferences: True | Location: True
# -> Selected Strategy: HYBRID (Collaborative + Content)
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# Cell In[64], line 11
#       9 u1 = users_to_test['has_ratings'][True][0]
#      10 print(f"\n--- Case 1: User {u1} (Has Ratings) ---")
# ---> 11 recs = get_smart_recommendations(mysql_engine, mongo_db, u1, limit=5)
#      12 for book in recs:
#      13     print(f"- {book.get('title', 'Unknown')} (Score: {book.get('score', 0):.2f})")
#
# File ~/Desktop/MASTERS/Database_ADV/book_rec_project/scripts/recommendations/recommendation_smart.py:128, in get_smart_recommendations(mysql_engine, mongo_db, user_id, limit)
#     126 if status['has_ratings']:
#     127     print("-> Selected Strategy: HYBRID (Collaborative + Content)")
# --> 128     return get_hybrid_recommendations(mysql_engine, mongo_db, user_id, limit)
#     130 # Priority 2: Preferences (Onboarding data)
#     131 elif status['has_preferences']:
#
# File ~/Desktop/MASTERS/Database_ADV/book_rec_project/scripts/recommendations/recommendation_hybrid.py:210, in get_hybrid_recommendations(mysql_engine, mongo_db, user_id, limit, content_weight, collab_weight, popularity_weight)
#     207 rated_isbns = set(user_ratings.keys())
#     209 # Find similar users for collaborative filtering
# --> 210 similar_users = find_similar_users_simple(mysql_engine, user_id)
#     212 # Get candidate books (from user preferences and similar users)
#     213 candidate_isbns = set()
#
# File ~/Desktop/MASTERS/Database_ADV/book_rec_project/scripts/recommendations/recommendation_hybrid.py:157, in find_similar_users_simple(mysql_engine, target_user_id, min_common_books, limit)
#     154 target_books = set(target_ratings.keys())
#     156 with mysql_engine.connect() as conn:
# --> 157     result = conn.execute(text("""
#     158         SELECT DISTINCT user_id
#     159         FROM ratings
#     160         WHERE isbn IN :isbns AND user_id != :target_user_id
#     161     """), {"isbns": tuple(target_books), "target_user_id": target_user_id})
#     163     candidate_users = [row[0] for row in result.fetchall()]
#     165 similar_users = []
#
# File ~/Desktop/MASTERS/Database_ADV/book_rec_project/db_venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File ~/Desktop/MASTERS/Database_ADV/book_rec_project/db_venv/lib/python3.13/site-packages/sqlalchemy/sql/elements.py:526, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     524     if TYPE_CHECKING:
#     525         assert isinstance(self, Executable)
# --> 526     return connection._execute_clauseelement(
#     527         self, distilled_params, execution_options
#     528     )
#     529 else:
#     530     raise exc.ObjectNotExecutableError(self)
#
# File ~/Desktop/MASTERS/Database_ADV/book_rec_project/db_venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1629 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1630     "compiled_cache", self.engine._compiled_cache
#    1631 )
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)   1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#    1654     self.dispatch.after_execute(
#    1655         self,
#    1656         elem,
#    (...)   1660         ret,
#    1661     )
#
# File ~/Desktop/MASTERS/Database_ADV/book_rec_project/db_venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/Desktop/MASTERS/Database_ADV/book_rec_project/db_venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/Desktop/MASTERS/Database_ADV/book_rec_project/db_venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2358, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2356     else:
#    2357         assert exc_info[1] is not None
# -> 2358         raise exc_info[1].with_traceback(exc_info[2])
#    2359 finally:
#    2360     del self._reentrant_error
#
# File ~/Desktop/MASTERS/Database_ADV/book_rec_project/db_venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)   1978         context.executemany,
#    1979     )
#
# File ~/Desktop/MASTERS/Database_ADV/book_rec_project/db_venv/lib/python3.13/site-packages/sqlalchemy/engine/default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# File ~/Desktop/MASTERS/Database_ADV/book_rec_project/db_venv/lib/python3.13/site-packages/mysql/connector/cursor_cext.py:328, in CMySQLCursor.execute(self, operation, params, map_results)
#     325     raise ProgrammingError(str(err)) from err
#     327 if params:
# --> 328     prepared = self._connection.prepare_for_mysql(params)
#     329     if isinstance(prepared, dict):
#     330         stmt = _bytestr_format_dict(stmt, prepared)
#
# File ~/Desktop/MASTERS/Database_ADV/book_rec_project/db_venv/lib/python3.13/site-packages/mysql/connector/connection_cext.py:955, in CMySQLConnection.prepare_for_mysql(self, params)
#     953     else:
#     954         for key, value in params.items():
# --> 955             result[key.encode()] = self._cmysql.convert_to_mysql(value)[0]
#     956 else:
#     957     raise ProgrammingError(
#     958         f"Could not process parameters: {type(params).__name__}({params}),"
#     959         " it must be of type list, tuple or dict"
#     960     )
#
# MySQLInterfaceError: Python type tuple cannot be converted
